# %%
# !pip install agency-swarm gradio duckduckgo-search
# Out:
# Collecting agency-swarm
#   Downloading agency_swarm-0.1.6-py3-none-any.whl.metadata (11 kB)
# Collecting gradio
#   Downloading gradio-4.25.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: duckduckgo-search in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (5.2.2)
# Collecting openai==1.14.2 (from agency-swarm)
#   Downloading openai-1.14.2-py3-none-any.whl.metadata (19 kB)
# Collecting instructor==0.6.7 (from agency-swarm)
#   Downloading instructor-0.6.7-py3-none-any.whl.metadata (11 kB)
# Collecting deepdiff==6.7.1 (from agency-swarm)
#   Downloading deepdiff-6.7.1-py3-none-any.whl.metadata (6.1 kB)
# Collecting termcolor==2.3.0 (from agency-swarm)
#   Downloading termcolor-2.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: python-dotenv==1.0.0 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from agency-swarm) (1.0.0)
# Collecting rich==13.7.0 (from agency-swarm)
#   Downloading rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting jsonref==1.1.0 (from agency-swarm)
#   Downloading jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting ordered-set<4.2.0,>=4.0.2 (from deepdiff==6.7.1->agency-swarm)
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from instructor==0.6.7->agency-swarm) (3.9.3)
# Requirement already satisfied: docstring-parser<0.16,>=0.15 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from instructor==0.6.7->agency-swarm) (0.15)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.2 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from instructor==0.6.7->agency-swarm) (2.6.4)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from instructor==0.6.7->agency-swarm) (8.2.3)
# Requirement already satisfied: typer<0.10.0,>=0.9.0 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from instructor==0.6.7->agency-swarm) (0.9.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from openai==1.14.2->agency-swarm) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from openai==1.14.2->agency-swarm) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from openai==1.14.2->agency-swarm) (0.27.0)
# Requirement already satisfied: sniffio in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from openai==1.14.2->agency-swarm) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from openai==1.14.2->agency-swarm) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from openai==1.14.2->agency-swarm) (4.10.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from rich==13.7.0->agency-swarm) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from rich==13.7.0->agency-swarm) (2.17.2)
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Collecting altair<6.0,>=4.2.0 (from gradio)
#   Downloading altair-5.3.0-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: fastapi in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from gradio) (0.110.1)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.3.2.tar.gz (5.5 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gradio-client==0.15.0 (from gradio)
#   Downloading gradio_client-0.15.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from gradio) (0.22.2)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from gradio) (6.4.0)
# Collecting jinja2<4.0 (from gradio)
#   Downloading Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from gradio) (2.1.5)
# Collecting matplotlib~=3.0 (from gradio)
#   Downloading matplotlib-3.8.3-cp311-cp311-win_amd64.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy~=1.0 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from gradio) (3.10.0)
# Requirement already satisfied: packaging in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from gradio) (23.2)
# Collecting pandas<3.0,>=1.0 (from gradio)
#   Downloading pandas-2.2.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting pillow<11.0,>=8.0 (from gradio)
#   Downloading pillow-10.3.0-cp311-cp311-win_amd64.whl.metadata (9.4 kB)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.9 (from gradio)
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from gradio) (6.0.1)
# Collecting ruff>=0.2.2 (from gradio)
#   Downloading ruff-0.3.5-py3-none-win_amd64.whl.metadata (24 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio)
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from gradio) (0.29.0)
# Requirement already satisfied: fsspec in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from gradio-client==0.15.0->gradio) (2024.3.1)
# Collecting websockets<12.0,>=10.0 (from gradio-client==0.15.0->gradio)
#   Downloading websockets-11.0.3-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: click>=8.1.7 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from duckduckgo-search) (8.1.7)
# Requirement already satisfied: curl-cffi>=0.6.2 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from duckduckgo-search) (0.6.2)
# Collecting jsonschema>=3.0 (from altair<6.0,>=4.2.0->gradio)
#   Downloading jsonschema-4.21.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting toolz (from altair<6.0,>=4.2.0->gradio)
#   Downloading toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: colorama in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from click>=8.1.7->duckduckgo-search) (0.4.6)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from curl-cffi>=0.6.2->duckduckgo-search) (1.16.0)
# Requirement already satisfied: certifi in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from curl-cffi>=0.6.2->duckduckgo-search) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from httpx<1,>=0.23.0->openai==1.14.2->agency-swarm) (1.0.5)
# Requirement already satisfied: idna in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from httpx<1,>=0.23.0->openai==1.14.2->agency-swarm) (3.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.14.2->agency-swarm) (0.14.0)
# Requirement already satisfied: filelock in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (3.13.3)
# Requirement already satisfied: requests in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Collecting contourpy>=1.0.1 (from matplotlib~=3.0->gradio)
#   Downloading contourpy-1.2.1-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib~=3.0->gradio)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib~=3.0->gradio)
#   Downloading fonttools-4.50.0-cp311-cp311-win_amd64.whl.metadata (162 kB)
#      ---------------------------------------- 0.0/162.6 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.6 kB ? eta -:--:--
#      ------ ------------------------------ 30.7/162.6 kB 660.6 kB/s eta 0:00:01
#      ------------- ----------------------- 61.4/162.6 kB 469.7 kB/s eta 0:00:01
#      ---------------- -------------------- 71.7/162.6 kB 438.9 kB/s eta 0:00:01
#      ------------------------ ----------- 112.6/162.6 kB 504.4 kB/s eta 0:00:01
#      --------------------------- -------- 122.9/162.6 kB 481.4 kB/s eta 0:00:01
#      ------------------------------------ 162.6/162.6 kB 488.3 kB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib~=3.0->gradio)
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib~=3.0->gradio)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mgsuk\miniconda3\envs\agentsf\lib\site-packages (
1 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.2 MB 4.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.0/2.2 MB 4.1 MB/s eta 0:00:01
#    --------------------- ------------------ 1.2/2.2 MB 3.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.2 MB 3.8 MB/s eta 0:00:01
#    --------------------------- ------------ 1.5/2.2 MB 3.8 MB/s eta 0:00:01
#    ------------------------------ --------- 1.7/2.2 MB 3.8 MB/s eta 0:00:01
#    -------------------------------- ------- 1.8/2.2 MB 3.7 MB/s eta 0:00:01
#    --------------------------------- ------ 1.9/2.2 MB 3.5 MB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 3.4 MB/s eta 0:00:00
# Downloading jsonschema-4.21.1-py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.5 kB ? eta -:--:--
#    ---------------------------------------- 85.5/85.5 kB 5.0 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB 2.9 MB/s eta 0:00:00
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ---------------------------------------- 103.2/103.2 kB 6.2 MB/s eta 0:00:00
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ---------------------------------------- 0.0/505.5 kB ? eta -:--:--
#    ----------- ---------------------------- 143.4/505.5 kB 4.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 286.7/505.5 kB 4.4 MB/s eta 0:00:01
#    ------------------------------------ --- 460.8/505.5 kB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 505.5/505.5 kB 4.0 MB/s eta 0:00:00
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    -------------- ------------------------- 122.9/345.4 kB 7.0 MB/s eta 0:00:01
#    --------------------------------- ------ 286.7/345.4 kB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 345.4/345.4 kB 3.6 MB/s eta 0:00:00
# Downloading websockets-11.0.3-cp311-cp311-win_amd64.whl (124 kB)
#    ---------------------------------------- 0.0/124.7 kB ? eta -:--:--
#    ---------------------------------------- 124.7/124.7 kB 3.7 MB/s eta 0:00:00
# Downloading toolz-0.12.1-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB 3.1 MB/s eta 0:00:00
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading referencing-0.34.0-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.18.0-cp311-none-win_amd64.whl (206 kB)
#    ---------------------------------------- 0.0/206.7 kB ? eta -:--:--
#    ----------------------- ---------------- 122.9/206.7 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 206.7/206.7 kB 3.2 MB/s eta 0:00:00
# Building wheels for collected packages: ffmpy
#   Building wheel for ffmpy (setup.py): started
#   Building wheel for ffmpy (setup.py): finished with status 'done'
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5605 sha256=034c14044f6f726b5e18db8df30bdfee2657f348a8f02a7f0b71538dff920f8a
#   Stored in directory: c:\users\mgsuk\appdata\local\pip\cache\wheels\55\3c\f2\f6e34046bac0d57c13c7d08123b85872423b89c8f59bafda51
# Successfully built ffmpy
# Installing collected packages: pytz, pydub, ffmpy, websockets, tzdata, toolz, tomlkit, termcolor, shellingham, semantic-version, ruff, rpds-py, python-multipart, pyparsing, pillow, ordered-set, kiwisolver, jsonref, jinja2, fonttools, cycler, contourpy, aiofiles, rich, referencing, pandas, matplotlib, deepdiff, openai, jsonschema-specifications, gradio-client, jsonschema, instructor, altair, agency-swarm, gradio
#   Attempting uninstall: websockets
#     Found existing installation: websockets 12.0
#     Uninstalling websockets-12.0:
#       Successfully uninstalled websockets-12.0
#   Attempting uninstall: rich
#     Found existing installation: rich 13.7.1
#     Uninstalling rich-13.7.1:
#       Successfully uninstalled rich-13.7.1
#   Attempting uninstall: openai
#     Found existing installation: openai 1.16.1
#     Uninstalling openai-1.16.1:
#       Successfully uninstalled openai-1.16.1
#   Attempting uninstall: instructor
#     Found existing installation: instructor 0.5.2
#     Uninstalling instructor-0.5.2:
#       Successfully uninstalled instructor-0.5.2
# Successfully installed agency-swarm-0.1.6 aiofiles-23.2.1 altair-5.3.0 contourpy-1.2.1 cycler-0.12.1 deepdiff-6.7.1 ffmpy-0.3.2 fonttools-4.50.0 gradio-4.25.0 gradio-client-0.15.0 instructor-0.6.7 jinja2-3.1.3 jsonref-1.1.0 jsonschema-4.21.1 jsonschema-specifications-2023.12.1 kiwisolver-1.4.5 matplotlib-3.8.3 openai-1.14.2 ordered-set-4.1.0 pandas-2.2.1 pillow-10.3.0 pydub-0.25.1 pyparsing-3.1.2 python-multipart-0.0.9 pytz-2024.1 referencing-0.34.0 rich-13.7.0 rpds-py-0.18.0 ruff-0.3.5 semantic-version-2.10.0 shellingham-1.5.4 termcolor-2.3.0 tomlkit-0.12.0 toolz-0.12.1 tzdata-2024.1 websockets-11.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# crewai 0.22.5 requires instructor<0.6.0,>=0.5.2, but you have instructor 0.6.7 which is incompatible.
# yt-dlp 2023.12.30 requires websockets>=12.0, but you have websockets 11.0.3 which is incompatible.

# %%
from agency_swarm import set_openai_key
from getpass import getpass
set_openai_key(getpass("Please enter your openai key: "))
# Out:
# Please enter your openai key: ··········

# %% [markdown]
# # CEO Agent

# %%
ceo_instructions = """# Instructions for CEO Agent

- Ensure that proposal is send to the user before proceeding with task execution.
- Delegate tasks to appropriate agents, ensuring they align with their expertise and capabilities.
- Clearly define the objectives and expected outcomes for each task.
- Provide necessary context and background information for successful task completion.
- Maintain ongoing communication with agents until complete task execution.
- Review completed tasks to ensure they meet the set objectives.
- Report the results back to the user."""

# %%
from agency_swarm import Agent

ceo = Agent(name="CEO",
            description="Responsible for client communication, task planning and management.",
            instructions=ceo_instructions, # can be a file like ./instructions.md
            files_folder=None,
            tools=[])

# %% [markdown]
# # Virtual Assistant

# %% [markdown]
# ### Importing tools from langchain example.
# You can skip these and remove them from va agent below.

# %%
# !pip install langchain==0.0.318 &> /dev/null

# %%
from langchain.utilities.zapier import ZapierNLAWrapper
from langchain.agents.agent_toolkits import ZapierToolkit
import os
from langchain.tools import format_tool_to_openai_function
from langchain.tools.zapier.tool import ZapierNLARunAction

# https://nla.zapier.com/docs/authentication/
os.environ["ZAPIER_NLA_API_KEY"] = getpass("Your Zapier NLA Key: ")
# Out:
# Your Zapier NLA Key: ··········

# %%
from agency_swarm import BaseTool
from pydantic import Field

actions = ZapierNLAWrapper().list()

class FindEmail(BaseTool):
    """Use this tool to find an email in user's mailbox"""
    instructions: str = Field(..., description="The search phrase you want to use to find a relevant email.")

    def run(self):
      action = next(
          (a for a in actions if a["description"].startswith("Gmail: Find Email")), None
      )
      return str(ZapierNLARunAction(
              action_id=action["id"],
              zapier_description=action["description"],
              params_schema=action["params"],
          ).run(self.search_string))

class DraftEmail(BaseTool):
    """Use this tool to draft a response email"""
    instructions: str = Field(..., description="Clearly outline in natural language the content of the email you need to draft and the address of the recepient.")

    def run(self):
        action = next(
            (a for a in actions if a["description"].startswith("Gmail: Create Draft Reply")), None
        )
        return str(ZapierNLARunAction(
                action_id=action["id"],
                zapier_description=action["description"],
                params_schema=action["params"],
            ).run(self.instructions))

# %% [markdown]
# ### Custom tools

# %%
from duckduckgo_search import DDGS
from agency_swarm.util.oai import get_openai_client

client = get_openai_client()


class SearchWeb(BaseTool):
    """Search the web with a search phrase and return the results."""

    phrase: str = Field(..., description="The search phrase you want to use. Optimize the search phrase for an internet search engine.")

    # This code will be executed if the agent calls this tool
    def run(self):
      with DDGS() as ddgs:
        return str([r for r in ddgs.text(self.phrase, max_results=3)])

class GenerateProposal(BaseTool):
    """Generate a proposal for a project based on a project brief. Remember that user does not have access to the output of this function. You must send it back to him after execution."""
    project_brief: str = Field(..., description="The project breif to generate a proposal for.")

    def run(self):
        completion = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[
              {"role": "system", "content": "You are a professional proposal drafting assistant. Do not include any actual technologies or technical details into proposal until specified in the project brief. Be short."},
              {"role": "user", "content": "Please draft a proposal for the ollowing project brief: " + self.project_brief}
            ]
          )

        return str(completion.choices[0].message.content)

# %%
va_instructions = """### Instructions for Virtual Assistant

Your role is to assist users in executing tasks like below. If the task is outside of your capabilities, please report back to the user.

#### 1. Drafting Emails
   - **Understand Context and Tone**: Familiarize yourself with the context of each email. Maintain a professional and courteous tone.
   - **Accuracy and Clarity**: Ensure that the information is accurate and presented clearly. Avoid jargon unless it's appropriate for the recipient.

#### 2. Generating Proposals
   - **Gather Requirements**: Collect all necessary information about the project, including client needs, objectives, and any specific requests.

#### 3. Conducting Research
   - **Understand the Objective**: Clarify the purpose and objectives of the research to focus on relevant information.
   - **Summarize Findings**: Provide clear, concise summaries of the research findings, highlighting key points and how they relate to the project or inquiry.
   - **Cite Sources**: Properly cite all sources to maintain integrity and avoid plagiarism.
"""

# %%
va = Agent(name="Virtual Assistant",
            description="Responsible for drafting emails, doing research and writing proposals.",
            instructions=va_instructions,
            files_folder=None,
            tools=[SearchWeb, FindEmail, DraftEmail, GenerateProposal])

# %% [markdown]
# # Developer Agent

# %%
from agency_swarm.tools import BaseTool
from pydantic import Field, BaseModel
import subprocess
from typing import List


class ExecuteCommand(BaseTool):
    """Run any command from the terminal. If there are too many logs, the outputs might be truncated."""
    command: str = Field(
        ..., description="The command to be executed."
    )

    def run(self):
        """Executes the given command and captures its output and errors."""
        try:
            # Splitting the command into a list of arguments
            command_args = self.command.split()

            # Executing the command
            result = subprocess.run(
                command_args,
                text=True,
                capture_output=True,
                check=True
            )
            return result.stdout
        except subprocess.CalledProcessError as e:
            return f"An error occurred: {e.stderr}"

class File(BaseTool):
    """
    File to be written to the disk with an appropriate name and file path, containing code that can be saved and executed locally at a later time.
    """
    file_name: str = Field(
        ..., description="The name of the file including the extension and the file path from your current directory if needed."
    )
    body: str = Field(..., description="Correct contents of a file")

    def run(self):
        # Extract the directory path from the file name
        directory = os.path.dirname(self.file_name)

        # If the directory is not empty, check if it exists and create it if not
        if directory and not os.path.exists(directory):
            os.makedirs(directory)

        # Write the file
        with open(self.file_name, "w") as f:
            f.write(self.body)

        return "File written to " + self.file_name

class Program(BaseTool):
    """
    Set of files that represent a complete and correct program. This environment has access to all standard Python packages and the internet.
    """
    chain_of_thought: str = Field(...,
        description="Think step by step to determine the correct actions that are needed to implement the program.")
    files: List[File] = Field(..., description="List of files")

    def run(self):
      outputs = []
      for file in self.files:
        outputs.append(file.run())

      return str(outputs)

# %%
dev_instructions = """# Instructions for AI Developer Agent

- Write clean and efficient Python code.
- Structure your code logically, with `main.py` as the entry point.
- Ensure correct imports according to program structure.
- Execute your code to test for functionality and errors, before reporting back to the user.
- Anticipate and handle potential runtime errors.
- Provide clear error messages for easier troubleshooting.
- Debug any issues before reporting the results back to the user."""

# %%
from agency_swarm.tools import Retrieval, CodeInterpreter

dev = Agent(name="Developer",
            description="Responsible for running and executing Python Programs.",
            instructions=dev_instructions,
            files_folder=None,
            tools=[ExecuteCommand, Program])

# %% [markdown]
# # Create Agency

# %%
agency_manifesto = """# "VRSEN AI" Agency Manifesto

You are a part of a virtual AI development agency called "VRSEN AI"

Your mission is to empower businesses to navigate the AI revolution successfully."""

# %%
from agency_swarm import Agency

agency = Agency([
    ceo,
    [ceo, dev],
    [ceo, va],
    [dev, va]
], shared_instructions=agency_manifesto)

# %% [markdown]
# # Demo with Gradio

# %%
agency.demo_gradio(height=900)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://0f487e388df2ab184e.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://0f487e388df2ab184e.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
